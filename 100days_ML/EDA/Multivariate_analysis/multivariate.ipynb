# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic = sns.load_dataset("titanic")
titanic.head()

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Scatter plot :

# %%
# scatter plot
sns.scatterplot(tips, x="total_bill", y="tip" , hue='sex',style='smoker',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Bar plot: (numerical -categorical)

# %%
titnc = pd.read_csv('train.csv')
titnc.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(titnc, x='Pclass', y='Age' ,hue = 'Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# BOx Plot:

# %%
sns.boxplot(titnc, x='Sex', y='Age' , hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# Kdeplot:

# %%
sns.kdeplot(data=titanic[titanic['survived'] == 0], x='age', label='Did not survive', fill=True)
sns.kdeplot(data=titanic[titanic['survived'] == 1], x='age', label='Survived', fill=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
pd.crosstab(titnc['Pclass'], titnc['Survived']).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Pclass'>

# %%
sns.heatmap(pd.crosstab(titnc['Pclass'], titnc['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# ClusterMap:

# %%
sns.clustermap(pd.crosstab(titnc['Parch'], titnc['Survived']))

# %% [markdown]
# PairPlot:

# %%
sns.pairplot(iris, hue='species', palette='husl')

# %% [markdown]
# LinePlot:

# %%
flights.head(3)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132

# %%
nw = flights.groupby('year', as_index=False)['passengers'].sum()

# %%
sns.lineplot(nw, x='year', y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flights.pivot_table(index='month', columns='year', values='passengers')
# Out:
# C:\Users\mohot\AppData\Local\Temp\ipykernel_33944\4194827972.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights.pivot_table(index='month', columns='year', values='passengers')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...

# %%
flights.pivot_table(index='month', columns='year', values='passengers').plot(kind='bar')
# Out:
# C:\Users\mohot\AppData\Local\Temp\ipykernel_33944\3753095750.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights.pivot_table(index='month', columns='year', values='passengers').plot(kind='bar')
# <Axes: xlabel='month'>

# %%
sns.clustermap(flights.pivot_table(index='month', columns='year', values='passengers'))
# Out:
# C:\Users\mohot\AppData\Local\Temp\ipykernel_33944\792777217.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(index='month', columns='year', values='passengers'))
