# %%
import pandas as pd
import numpy as np
import requests

# %%
res = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(res.json()['results'])[['id', 'title','overview','vote_average', 'release_date','vote_count']]

# %%
temp_df.head()
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2   803796                             KPop Demon Hunters
# 3      240                          The Godfather Part II
# 4      424                               Schindler's List
# 5      389                                   12 Angry Men
# 6      129                                  Spirited Away
# 7      155                                The Dark Knight
# 8    19404                    Dilwale Dulhania Le Jayenge
# 9      497                                 The Green Mile
# 10  496243                                       Parasite
# 11     680                                   Pulp Fiction
# 12     122  The Lord of the Rings: The Return of the King
# 13  372058                                     Your Name.
# 14      13                                   Forrest Gump
# 15     429                 The Good, the Bad and the Ugly
# 16  157336                                   Interstellar
# 17     769                                     GoodFellas
# 18     346                                  Seven Samurai
#
#                                              overview  vote_average  \
# 0   Imprisoned in the 1940s for the double murder ...         8.712
# 1   Spanning the years 1945 to 1955, a chronicle o...         8.687
# 2   When K-pop superstars Rumi, Mira and Zoey aren...         8.599
# 3   In the continuing saga of the Corleone crime f...         8.571
# 4   The true story of how businessman Oskar Schind...         8.564
# 5   The defense and the prosecution have rested an...         8.549
# 6   A young girl, Chihiro, becomes trapped in a st...         8.536
# 7   Batman raises the stakes in his war on crime. ...         8.521
# 8   Raj is a rich, carefree, happy-go-lucky second...         8.518
# 9   A supernatural tale set on death row in a Sout...         8.505
# 10  All unemployed, Ki-taek's family takes peculia...         8.499
# 11  A burger-loving hit man, his philosophical par...         8.488
# 12  As armies mass for a final battle that will de...         8.487
# 13  High schoolers Mitsuha and Taki are complete s...         8.483
# 14  A man with a low IQ has accomplished great thi...         8.468
# 15  While the Civil War rages on between the Union...         8.463
# 16  The adventures of a group of explorers who mak...         8.456
# 17  The true story of Henry Hill, a half-Irish, ha...         8.455
# 18  A samurai answers a village's request for prot...         8.455
#
#    release_date  vote_count
# 0    1994-09-23       28487
# 1    1972-03-14       21577
# 2    2025-06-20         334
# 3    1974-12-20       13032
# 4    1993-12-15       16512
# 5    1957-04-10        9220
# 6    2001-07-20       17242
# 7    2008-07-16       34007
# 8    1995-10-20        4493
# 9    1999-12-10       18177
# 10   2019-05-30       19188
# 11   1994-09-10       28805
# 12   2003-12-17       25200
# 13   2016-08-26       11829
# 14   1994-06-23       28338
# 15   1966-12-22        9054
# 16   2014-11-05       37350
# 17   1990-09-12       13455
# 18   1954-04-26        3921
