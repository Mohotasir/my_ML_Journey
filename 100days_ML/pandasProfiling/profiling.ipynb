# %%
import pandas as pd

# %%
df = pd.read_csv('../EDA/Multivariate_analysis/train.csv')

# %%
# %pip install ydata-profiling
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------------------------- -------------- 1.8/2.8 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 7.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.8 MB 5.6 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.8 MB 5.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.8 MB 5.4 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.8 MB 5.2 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.8 MB 4.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.8 MB 4.4 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/9.8 MB 4.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.8 MB 4.1 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.8 MB 4.0 MB/s eta 0:00:01
# ...

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 66.32it/s]
